# %%
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
from plotly.graph_objs import Scatter, Figure, Layout
import csv

init_notebook_mode(connected=True)

column1, column2 = [], []
column3=[]
global column3

with open('data/cleaned/consolidated.csv') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        column1.append(row['Day of Week'])
        column2.append(row['RegNorm'])
        column3.append(float(row['CasNorm'])/float(row['RegNorm']))

iplot([Scatter(x=column1, y=column2, mode='markers')])
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# ...

# %%
iplot([Scatter(x=column1, y=column3, mode='markers')])
# Out:
# <div id="494cbe32-81c1-4318-b80f-b7ce5e1b0126" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("494cbe32-81c1-4318-b80f-b7ce5e1b0126", [{"mode": "markers", "y": [0.3336915597849971, 0.05639020508707027, 0.054118667447444604, 0.046345481458684584, 0.0596367172408845, 0.05976576090175942, 0.16816882831952823, 0.2031017607737664, 0.07296283542277776, 0.0634114344847376, 0.05066367410145087, 0.0714926707401757, 0.09238634597335708, 0.32110912059710467, 0.15220165577485537, 0.04304485415046669, 0.03570866630371331, 0.01726204410906271, 0.04710485199703586, 0.0702205878791382, 0.18523742746799793, 0.16804407292655538, 0.04643854881797931, 0.028158294121515395, 0.03465813052330099, 0.02190132257606416, 0.041040322491998474, 0.08327452560636567, 0.13837638522404266, 0.050314478651740845, 0.02630744936473557
# ...

# %%
column1 , column2 = [], []
with open('data/cleaned/2011-2017-Q1-bike-trips.csv') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        column1.append(row['dow'])
        column2.append(float(row['registered'])/float(row['total']))

iplot([Scatter(x=column1, y=column2, mode='markers')])
# Out:
# <div id="1bcfdb71-52a1-41b1-bd9e-aa981048e710" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("1bcfdb71-52a1-41b1-bd9e-aa981048e710", [{"mode": "markers", "y": [0.9749702026221693, 0.9779497098646035, 0.9430202891507715, 0.9173479816044967, 0.9098545380045072, 0.9517434620174346, 0.836253515033528, 0.7319030461840812, 0.952755905511811, 0.9593202883625128, 0.7959001782531194, 0.9522563767168084, 0.9459607986810771, 0.8214285714285714, 0.8453825857519789, 0.9424630297005095, 0.7645900024624477, 0.9478075281334886, 0.8581653346057497, 0.9174690508940853, 0.9499413375048885, 0.7403349023844432, 0.8516250588789449, 0.9799259403625025, 0.8293135435992579, 0.8772766695576756, 0.9651162790697675, 0.870181771303339, 0.7700614016514927, 0.7915282392026578, 0.827365308804205, 0.7533598334279765, 0.9401477832
# ...

# %%
column1 , column2 = [], []
with open('data/cleaned/train.validation.csv') as csvfile:
    reader = csv.reader(csvfile)
    for row in reader:
        column1.append(row[2])
        column2.append(float(row[3]))

iplot([Scatter(x=column1, y=column2, mode='markers')])
# Out:
# <div id="d0369668-26a9-4d46-a500-298e96ecb029" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("d0369668-26a9-4d46-a500-298e96ecb029", [{"mode": "markers", "y": [0.162006834420628, 0.0760334176939614, 0.103735529299439, 0.164895930413172, 0.0883297090193642, 0.166784656970009, 0.161342211581625, 0.0897063994374121, 0.17969804836136, 0.156803766429085, 0.16792991436165, 0.170877531340405, 0.126669298836426, 0.18929344883595, 0.0311124156149105, 0.0750667259786477, 0.106475926780495, 0.126486944811591, 0.143049528654796, 0.17651842657193, 0.177165943438576, 0.172096908939014, 0.209976376521897, 0.151468258354519, 0.100436321725529, 0.120124721603563, 0.15137735024049, 0.123090481786134, 0.185137683892871, 0.104730543731427, 0.138931364410852, 0.0737819195773408, 0.0982714138286894, 0.159251670378619, 
# ...
